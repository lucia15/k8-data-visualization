# %% [markdown]
# <a href="https://colab.research.google.com/github/baker371/k8-data-visualization/blob/lwasampijja-baker/upwork-devs/lwasampijja-baker/issues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Github Issues Visualisations

# %% [markdown]
# ### Table of Contents
#
# * [Importing Dependencies](#install)
# * [Pie Chart Showing Open/Closed Issues](#pie_state)
# * [A Bar Graph Showing the Number of Issues per Repo](#bar_repo)
# * [A Bar Graph Showing the Number of Issues per Date](#chart_date)
# * [A Bar Graph Showing the Number of Issues per User](#chart_user)
# * [A Table Showing the Number and Status of Issues per Repo](#table_state)
# * [A Bar Graph Showing Open/Closed Issues per User](#barnow)
# * [Pie Chart Showing User Association with the Repo](#pietwo)
# * [A Network Graph of Users and Issues Generated](#network)

# %% [markdown]
# <a id="install"></a>
#
# ### Importing Dependencies

# %%
#@title

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# !cp "/content/drive/My Drive/models/issues.py" .

from issues import *

repos = Repos.get_repos()

issues = Issues(repos)

df = issues.get_df()
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a id="pie_state"></a>
#
# ### Pie Chart Showing Open/Closed Issues

# %%
#@title
## Pie Chart Showing Issue Status

issues.show_pie('state')

# %% [markdown]
# <a id="bar_repo"></a>
#
# ### A Bar Graph Showing the Number of Issues per Repo

# %%
#@title
issues.show_bar_chart_by_repo()

# %% [markdown]
# <a id="chart_user"></a>
#
# ### A Bar Graph Showing the Number of Issues Generated by User

# %%
#@title
issues.show_bar_chart_by_user()

# %% [markdown]
# <a id="table_state"></a>
#
# ### A Table Showing the Number and Status of Issues per Repo

# %%
#@title
issues.table_project_state()
# Out:
# state                                        closed  open
# repo
# Open-Source                                    24.0   6.0
# aws-jmeter-test-engine-v1                      17.0  13.0
# chrome-extension                                7.0  12.0
# icap-poc-load-balancer                          3.0   4.0
# k8-data-visualization                          24.0   6.0
# k8-glasswall-rebuild                           24.0   6.0
# k8-performance-use-cases                       17.0   6.0
# k8-proxy-desktop                               11.0  19.0
# k8-proxy-marketing                              5.0   0.0
# k8-reverse-proxy                               22.0   8.0
# k8-security                                     8.0  22.0
# k8-slack-bot                                   11.0  18.0
# k8-test-data                                   18.0  12.0
# k8-traffic-generator                           25.0   5.0
# k8-website-mass-file-download                   6.0   9.0
# k8-website-mass-file-download-analysis          1.0   1.0
# k8-website-mass-file-download-list-metadata     1.0   1.0
# p-design-requests                               2.0   3.0
# p-k8-jmeter-test-engine                        19.0  11.0
# p-k8-knative                                    0.0   6.0
# p-k8-kubernetes-10k-pods                        0.0   5.0
# p-k8-tech-radar                                10.0   2.0
# p-message-queue-service                         0.0   4.0
# p-threat-model-graph-visualisation              0.0   1.0
# p-ui-wireframes                                28.0   2.0
# p1-stakeholder-requests                         2.0   6.0
# s-gov-uk-prod                                  11.0   0.0

# %%
#@title
issues.show_state_repo()

# %% [markdown]
# <a id="barnow"></a>
#
# ### A Bar Graph Showing Open/Closed Issues per User

# %%
#@title
issues.show_state_user()

# %% [markdown]
# <a id="pietwo"></a>
#
# ### Pie Chart Showing User Association with the Repo

# %%
#@title
issues.show_pie_association()
