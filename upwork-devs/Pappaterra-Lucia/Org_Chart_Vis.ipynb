# %% [markdown]
# ## Organization Chart Visualization

# %%
import pandas as pd
import yaml
from aux_plot_func import graph, bar_plot, pie_chart

# %%
with open('org_chart.yml', 'r') as f:
    df = pd.json_normalize(yaml.load(f, Loader=yaml.FullLoader))
df
# Out:
#                         project_name  \
# 0         p-k8-performance-use-cases
# 1       p-k8-reverse-proxy-use-cases
# 2               p-data-visualisation
# 3                     p-k8-test-data
# 4             p-k8-traffic-generator
# 5   p-poc-desktopapp-electron-gatsby
# 6             p-k8-glasswall-rebuild
# 7                     p-k8-slack-bot
# 8         p-chrome-extension channel
# 9                  P-design-requests
# 10                S-k8-buildpipeline
# 11                         s-k8-core
# 12                          S-k8-ova
#
#                                  project_manager  \
# 0                                   Faisal Adnan
# 1                                 Mahmoud Nouman
# 2   [Chris Diao (Upwork), Susil Parida (Upwork)]
# 3                          Susil Parida (Upwork)
# 4                  [Faisal Adnan, Mark Bandillo]
# 5          [Jonathan Canales, Virendra Vaishnav]
# 6                                  Mark Bandillo
# 7                               Jonathan Canales
# 8                                Not Defined yet
# 9                                   No PM needed
# 10                                  No PM needed
# 11                                  No PM needed
# 12                             Georgina González
#
#                           resource_and_responsibility
# 0      [Rhia Rodríguez (Engineer), Marija (Engineer)]
# 1   [Nour eddine Yassine (Devep Engieer), Mariusz ...
# 2   [Lwasampija Bake (Data Science), Moses Mugo (D...
# 3   [Anish Argawal (Sr Dev/Dev Python), Samarth (D...
# 4                [Rhia (Engineer), Marija (Engineer)]
# 5   [Anish Agarwal, Giuseppe Mazzacua, Sanchit Gar...
# 6                                                None
# 7   [Giuseppe Mazzacua, Hunnain Pasha, Anish Agarwal]
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None

# %%
graph(df)

# %%
bar_plot(df)

# %%
pie_chart(df)
