# %% [markdown]
# <b> Testing the module</b>

# %%
repos = ['mvp-icap-service', 'mvp-icap-squid-cache-proxy', 'rebuild-k8s-filetypedetection',\
       'icap-performance-tests', 'rebuild-k8s']

# %%
from k8libs import gitlib
df = gitlib.Issues.get_pr_raw(repos)

# %%
df.head()
# Out:
#    number locked  created_at  updated_at   state   closed_at  \
# 0    16.0  False  2020-08-30  2020-08-30    open         NaT
# 1    15.0  False  2020-08-28  2020-08-28    open         NaT
# 2    14.0  False  2020-08-28  2020-08-28  closed  2020-08-28
# 3    11.0  False  2020-08-27  2020-08-27  closed  2020-08-27
# 4    10.0  False  2020-08-26  2020-08-27  closed  2020-08-27
#
#               merged_at                                requested_reviewers  \
# 0                  None                                                 []
# 1                  None  [{'login': 'Diggers89', 'id': 9385215, 'node_i...
# 2  2020-08-28T14:43:21Z                                                 []
# 3  2020-08-27T13:29:07Z                                                 []
# 4  2020-08-27T09:08:00Z                                                 []
#
#   labels author_association  user.login      project_name active_lock_reason  \
# 0     []     NO ASSOCIATION  IslamHeggy  mvp-icap-service               None
# 1     []        CONTRIBUTOR     BigPeeg  mvp-icap-service               None
# 2     []        CONTRIBUTOR     BigPeeg  mvp-icap-service               None
# 3     []        CONTRIBUTOR     BigPeeg  mvp-icap-service               None
# 4     []        CONTRIBUTOR     BigPeeg  mvp-icap-service               None
#
#   PR_duration
# 0         NaT
# 1         NaT
# 2      1 days
# 3      1 days
# 4      2 days

# %%
gitlib.Issues.get_pr_inferences(repos, df)
# Out:
# |------------------------------------------SUMMARY OF PR-----------------------------------------|
# Total number of unique PR: 16
# Total number of unique projects: 4
# Total number of unique users: 9
# First PR created on: 2020-07-16
# Last PR created on: 2020-08-31
# Average number of PR created per day: 0.348
# Average number of PR created per project: 4.0
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-------------------------------------------STATE OF PR-------------------------------------------|
# Number of open PR: 3
# Number of closed PR: 13
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-------------------------------------------DURATION OF PR----------------------------------------|
# Average duration of a closed PR (days): 1.538
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |--------------------------------------SPREAD OF DURATION OF PR-----------------------------------|
# Median duration of a PR, not closed on the same day (days): 2.0
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |---------------------------------------COUNT OF PR BY PROJECTS-----------------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |--------------------------------SPREAD OF DURATION OF PR BY PROJECTS-----------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-------------------------------------------PR COUNT BY USER--------------------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-------------------------------------PR COUNT OF AUTHOR ASSOCIATION--------------------------------|
