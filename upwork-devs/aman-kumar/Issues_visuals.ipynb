# %% [markdown]
# <b> Testing the module</b>

# %%
repos = ['mvp-icap-service', 'mvp-icap-squid-cache-proxy', 'rebuild-k8s-filetypedetection',\
       'icap-performance-tests', 'rebuild-k8s']

# %%
from k8libs import gitlib
df = gitlib.Issues.get_issues_raw(repos)

# %%
df.head()
# Out:
#    created_at   state   closed_at  user.login author_association  \
# 0  2020-08-30    open         NaT  IslamHeggy     NO ASSOCIATION
# 1  2020-08-28    open         NaT     BigPeeg        CONTRIBUTOR
# 2  2020-08-28  closed  2020-08-28     BigPeeg        CONTRIBUTOR
# 3  2020-08-27    open         NaT    dtollaku     NO ASSOCIATION
# 4  2020-08-27    open         NaT    dtollaku     NO ASSOCIATION
#
#                                                title  \
# 0                   add build and deploy to the repo
# 1         Addition of Az CLI instructions to readmie
# 2                                       Pg/sb listen
# 3  Extend workflow to deploy container from regis...
# 4  Add a workflow to build the image and upload i...
#
#                                                 body milestone.title  \
# 0  Building the mvp icap service and pushing the ...             NaN
# 1  Instructions on how to retrieve the necessary ...             NaN
# 2  Proxy App listens for Transaction Outcome mess...             NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   milestone.state      project_name project_duration
# 0             NaN  mvp-icap-service              NaT
# 1             NaN  mvp-icap-service              NaT
# 2             NaN  mvp-icap-service           1 days
# 3             NaN  mvp-icap-service              NaT
# 4             NaN  mvp-icap-service              NaT

# %%
gitlib.Issues.get_issues_inferences(repos, df)
# Out:
# |-----------------------------------------SUMMARY OF ISSUES---------------------------------------|
# Total number of unique Issues: 68
# Total number of unique projects: 5
# Total number of unique users: 12
# First Issue created on: 2020-07-16
# Last Issue created on: 2020-08-31
# Average number of issues created per day: 1.478
# Average number of issues created per project: 13.6
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-----------------------------------------STATE OF ISSUES-----------------------------------------|
# Number of open issues: 44
# Number of closed issues: 24
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-----------------------------------------DURATION OF ISSUES--------------------------------------|
# Average duration of a closed issue (days): 5.667
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |------------------------------------SPREAD OF DURATION OF ISSUES---------------------------------|
# Median duration of an issue, not closed on the same day (days): 11.0
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-------------------------------------COUNT OF ISSUES BY PROJECTS---------------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |------------------------------SPREAD OF DURATION OF ISSUES BY PROJECTS---------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-----------------------------------------ISSUE COUNT BY USER-------------------------------------|
# |-------------------------------------------------------------------------------------------------|
#
#
#
#
# |-----------------------------------ISSUE COUNT OF AUTHOR ASSOCIATION------------------------------|
