# %% [markdown]
# <a href="https://colab.research.google.com/github/baker371/k8-data-visualization/blob/lwasampijja-baker/k8_traffic_generator_issues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp "/content/drive/My Drive/models/k8_issues.py" .

# %%
from k8_issues import Issues

# %%
repos = ['k8-traffic-generator']

# %%
issues = Issues(repos)

df = issues.get_df()

issues.important()

# %%
issues.status()
# Out:
# Issue               closed  open
# Assignee
# DinisCruz              1.0   0.0
# Unassigned             7.0   1.0
# belwase                1.0   1.0
# faisaladnanpeltops     3.0   1.0
# ggrig                  2.0   2.0
# pranaysahith           1.0   2.0
# reem-masoud            1.0   0.0
# xuxant                 1.0   0.0
# yardenshoham           5.0   1.0
