# %% [markdown]
# <a href="https://colab.research.google.com/github/baker371/k8-data-visualization/blob/lwasampijja-baker/issues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Github Issues Visualisations

# %% [markdown]
# ### Table of Contents
#
# * [Importing Dependencies](#install)
# * [Pie Chart Showing Open/Closed Issues](#pie_state)
# * [A Bar Graph Showing the Number of Issues per Repo](#bar_repo)
# * [A Bar Graph Showing the Number of Issues per Date](#chart_date)
# * [A Bar Graph Showing the Number of Issues per User](#chart_user)
# * [A Table Showing the Number and Status of Issues per Repo](#table_state)
# * [A Bar Graph Showing Open/Closed Issues per User](#barnow)
# * [Pie Chart Showing User Association with the Repo](#pietwo)
# * [A Network Graph of Users and Issues Generated](#network)

# %% [markdown]
# <a id="install"></a>
#
# ### Importing Dependencies

# %%
#@title

# !cp "/content/drive/My Drive/models/issues.py" .

from issues import Issues

repos = ['mvp-icap-service', 'mvp-icap-cloud', 'mvp-icap-squid-cache-proxy',
         'rebuild-k8s-filetypedetection', 'icap-performance-tests', 'rebuild-k8s', 'c-icap', 'k8-glasswall-rebuild',
         'k8-data-visualization']

issues = Issues(repos)

df = issues.get_df()

issues.important()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# <a id="pie_state"></a>
#
# ### Pie Chart Showing Open/Closed Issues

# %%
#@title
## Pie Chart Showing Issue Status

issues.show_pie('state')
# Out:
# closed    145
# open       80
# Name: state, dtype: int64

# %% [markdown]
# <a id="bar_repo"></a>
#
# ### A Bar Graph Showing the Number of Issues per Repo

# %%
#@title
issues.show_bar_chart_by_repo()

# %% [markdown]
# <a id="chart_date"></a>
#
# ### A Bar Graph Showing the Number of Issues per Date

# %%
#@title
issues.show_bar_chart_by_date()

# %% [markdown]
# <a id="chart_user"></a>
#
# ### A Bar Graph Showing the Number of Issues per User

# %%
#@title
issues.show_bar_chart_by_user()

# %% [markdown]
# <a id="table_state"></a>
#
# ### A Table Showing the Number and Status of Issues per Repo

# %%
#@title
issues.table_project_state()
# Out:
# state                          closed  open
# repo
# c-icap                           23.0   7.0
# icap-performance-tests           18.0   6.0
# k8-data-visualization            10.0  20.0
# k8-glasswall-rebuild             20.0  10.0
# mvp-icap-cloud                   19.0  11.0
# mvp-icap-service                 16.0   8.0
# mvp-icap-squid-cache-proxy       19.0   7.0
# rebuild-k8s                      20.0  10.0
# rebuild-k8s-filetypedetection     0.0   1.0

# %% [markdown]
# <a id="barnow"></a>
#
# ### A Bar Graph Showing Open/Closed Issues per User

# %%
#@title
issues.show_state_user()

# %% [markdown]
# <a id="pietwo"></a>
#
# ### Pie Chart Showing User Association with the Repo

# %%
#@title
issues.show_pie_association('author_association')
# Out:
# COLLABORATOR    124
# CONTRIBUTOR      57
# NONE             44
# Name: author_association, dtype: int64

# %% [markdown]
# <a id="network"></a>
#
# ### A Network Graph of Users and Issues Generated

# %%
#@title
issues.show_en_graph()
